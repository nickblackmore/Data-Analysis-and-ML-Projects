# %% [markdown]
# # Mean Value Theorem Visualization

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Create two lists of random numbers
random_numbers_x = [random.randint(0,100) for i in range(1000)]
random_numbers_y = [random.randint(0,100) for i in range(1000)]
plt.scatter(random_numbers_x, random_numbers_y)

# %%
#Creates 1000 different sample sizes for every iteration
sample_size = random.randint(0,1000)
